# %% [markdown]
# ## Word2Vec Tutorial

# %% [markdown]
# ## 1. Preparing the Input

# %% [markdown]
# ** Import modules and Set up logging **

# %%
import gensim, logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level = logging.INFO)

# %%
sentences = [['My', 'father', 'is', 'a', 'King'], ['My', 'mother', 'is', 'a', 'Queen']]
model = gensim.models.Word2Vec(sentences, min_count = 1)

# %%
print model
# Out:
# Word2Vec(vocab=7, size=100, alpha=0.025)

# %%
model.save('word')

# %%
model1 = gensim.models.Word2Vec.load('word')

# %%
model['My']
# Out:
# array([ -1.54559384e-03,   4.59272997e-04,  -4.87498706e-03,
#          1.98480859e-03,  -8.92666052e-04,   4.01177211e-03,
#          4.59596195e-04,  -9.02279280e-05,   1.58030656e-03,
#          3.95178888e-03,   3.86670534e-03,  -4.93394630e-03,
#         -1.09239796e-03,   2.60674837e-03,   2.59770290e-03,
#          4.79952293e-03,  -3.10566067e-03,  -3.99377523e-03,
#         -3.52321193e-03,  -4.57987376e-03,   1.99176851e-04,
#         -1.80264923e-03,   4.54285508e-03,  -4.71079396e-03,
#          3.34477331e-03,   5.63906797e-04,   4.53675352e-03,
#         -1.64424535e-03,  -2.35176459e-03,  -4.79270420e-05,
#         -2.01396979e-05,  -2.34993378e-04,   7.50170220e-05,
#          3.59872269e-04,   3.00772744e-03,  -1.83727592e-03,
#         -1.01174146e-03,  -9.23481130e-04,  -4.62902989e-03,
#          3.56314192e-03,   4.53692256e-03,   3.23996856e-03,
#         -2.24557100e-03,  -3.98240471e-03,  -9.69609478e-04,
# ...

# %%
model1['My']
# Out:
# array([ -1.54559384e-03,   4.59272997e-04,  -4.87498706e-03,
#          1.98480859e-03,  -8.92666052e-04,   4.01177211e-03,
#          4.59596195e-04,  -9.02279280e-05,   1.58030656e-03,
#          3.95178888e-03,   3.86670534e-03,  -4.93394630e-03,
#         -1.09239796e-03,   2.60674837e-03,   2.59770290e-03,
#          4.79952293e-03,  -3.10566067e-03,  -3.99377523e-03,
#         -3.52321193e-03,  -4.57987376e-03,   1.99176851e-04,
#         -1.80264923e-03,   4.54285508e-03,  -4.71079396e-03,
#          3.34477331e-03,   5.63906797e-04,   4.53675352e-03,
#         -1.64424535e-03,  -2.35176459e-03,  -4.79270420e-05,
#         -2.01396979e-05,  -2.34993378e-04,   7.50170220e-05,
#          3.59872269e-04,   3.00772744e-03,  -1.83727592e-03,
#         -1.01174146e-03,  -9.23481130e-04,  -4.62902989e-03,
#          3.56314192e-03,   4.53692256e-03,   3.23996856e-03,
#         -2.24557100e-03,  -3.98240471e-03,  -9.69609478e-04,
# ...

# %%
model2 = gensim.models.word2vec.Word2Vec()

# %%
model.save_word2vec_format('vector', fvocab = None, binary=True)

# %%
model3 = gensim.models.Word2Vec.load_word2vec_format('vector', binary=True)

# %%
model3['My']
# Out:
# array([ -1.54559384e-03,   4.59272997e-04,  -4.87498706e-03,
#          1.98480859e-03,  -8.92666052e-04,   4.01177211e-03,
#          4.59596195e-04,  -9.02279280e-05,   1.58030656e-03,
#          3.95178888e-03,   3.86670534e-03,  -4.93394630e-03,
#         -1.09239796e-03,   2.60674837e-03,   2.59770290e-03,
#          4.79952293e-03,  -3.10566067e-03,  -3.99377523e-03,
#         -3.52321193e-03,  -4.57987376e-03,   1.99176851e-04,
#         -1.80264923e-03,   4.54285508e-03,  -4.71079396e-03,
#          3.34477331e-03,   5.63906797e-04,   4.53675352e-03,
#         -1.64424535e-03,  -2.35176459e-03,  -4.79270420e-05,
#         -2.01396979e-05,  -2.34993378e-04,   7.50170220e-05,
#          3.59872269e-04,   3.00772744e-03,  -1.83727592e-03,
#         -1.01174146e-03,  -9.23481130e-04,  -4.62902989e-03,
#          3.56314192e-03,   4.53692256e-03,   3.23996856e-03,
#         -2.24557100e-03,  -3.98240471e-03,  -9.69609478e-04,
# ...
